# %%
import pickle

# %%
with open('./dataset/dl_v1/df_train_dl_v1.pkl', 'rb') as f:
    df_train = pickle.load(f)

with open('./dataset/dl_v1/df_valid_dl_v1.pkl', 'rb') as f:
    df_valid = pickle.load(f)

# %%
train_x = df_train['x']
train_y = df_train['y']
valid_x = df_valid['x']
valid_y = df_valid['y']

# %%
len(train_x), len(train_y), len(valid_x), len(valid_y)
# Out:
# (5504, 5504, 680, 680)

# %%
train_y[0]
# Out:
#         timestamp  PM2.5
# 0   0_01-03_00:00  0.156
# 1   0_01-03_01:00  0.156
# 2   0_01-03_02:00  0.116
# 3   0_01-03_03:00  0.160
# 4   0_01-03_04:00  0.164
# ..            ...    ...
# 67  0_01-05_19:00  0.064
# 68  0_01-05_20:00  0.044
# 69  0_01-05_21:00  0.040
# 70  0_01-05_22:00  0.032
# 71  0_01-05_23:00  0.060
#
# [72 rows x 2 columns]

# %%
train_x[0]
# Out:
#     연도  측정소  PM2.5      timestamp  month  day  hour        기온        풍향
# 0    0  아름동  0.044  0_01-01_00:00      1    1     0  0.170616  0.053333  \
# 1    0  아름동  0.048  0_01-01_01:00      1    1     1  0.167457  0.099444
# 2    0  아름동  0.060  0_01-01_02:00      1    1     2  0.162717  0.134167
# 3    0  아름동  0.064  0_01-01_03:00      1    1     3  0.157978  0.000000
# 4    0  아름동  0.064  0_01-01_04:00      1    1     4  0.148499  0.000000
# 5    0  아름동  0.064  0_01-01_05:00      1    1     5  0.142180  0.000000
# 6    0  아름동  0.056  0_01-01_06:00      1    1     6  0.127962  0.000000
# 7    0  아름동  0.056  0_01-01_07:00      1    1     7  0.154818  0.000000
# 8    0  아름동  0.056  0_01-01_08:00      1    1     8  0.191153  0.574444
# 9    0  아름동  0.048  0_01-01_09:00      1    1     9  0.206951  0.331111
# 10   0  아름동  0.060  0_01-01_10:00      1    1    10  0.233807  0.120278
# 11   0  아름동  0.052  0_01-01_11:00      1    1    11  0.282780  0.000000
# ...
